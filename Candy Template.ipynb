# %% [markdown]
# # Project: cleanning - [candy data]
# ### this notebook is for educational purpose . in this notebook we will do some cleanning
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">wrangling</a></li>
#
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
# ### Dataset Description
#
# > i will go through candy data 2017 , this data has :
# - Internal_ID
# - Q1-Going Out?: Are you actually going trick or treating yourself? "has values `Yes or No`"
# - Q2-Gender: It has four different options, `Femal ,Male ,Other ,I'd rather not say`
# - Q3-Age: Numerical field
# - Q4-Country: Text Field, but users have written their own version of the names. Example, for America, there are entries such as USA, us, US, America so we should consider that while cleanning
# - Q5-State/Province: Text Field, but users have written their own version of the names. Same as the country data.
# - Q6-Joy Or Despair: All kinds of chocolate bars are the questions with three distinct options to choose from (Joy, Meh, Despair).
# - Q7-Joy Other: Text Field to write items not included above that give you JOY. Lots of missing values.
# - Q8-Despair Other: Text Field ti write items not included above that give you DESPAIR. Lots of missing values.
# - Q9-Other Comments: Text Field. Lots of missing values.
# - Q10-Dress: Binary field. Missing values present
# - Unnamed: 113
# - Q11-Day: Binary Answer Field. Missing values present

# %% [markdown]
# # 1- Import packages and load data

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', False)
pd.set_option('display.max_rows', None)

df = pd.read_excel("candyhierarchy2017.xlsx")
df.head()
# Out:
#    Internal ID Q1: GOING OUT? Q2: GENDER  ... Q12: MEDIA [ESPN] Q12: MEDIA [Yahoo] Click Coordinates (x, y)
# 0     90258773            NaN        NaN  ...               NaN                NaN                      NaN
# 1     90272821             No       Male  ...               NaN                NaN                 (84, 25)
# 2     90272829            NaN       Male  ...               NaN                NaN                      NaN
# 3     90272840             No       Male  ...               NaN                NaN                 (75, 23)
# 4     90272841             No       Male  ...               NaN                NaN                 (70, 10)
#
# [5 rows x 120 columns]

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling
#
#
#
# ### General Properties

# %% [markdown]
# # 2- Show some general properties for the data

# %%
df.shape
# Out:
# (2460, 120)

# %%
df.describe()
# Out:
#         Internal ID  Q12: MEDIA [Daily Dish]  Q12: MEDIA [Science]  Q12: MEDIA [ESPN]  Q12: MEDIA [Yahoo]
# count  2.460000e+03                     85.0                1362.0               99.0                67.0
# mean   9.028016e+07                      1.0                   1.0                1.0                 1.0
# std    7.435532e+03                      0.0                   0.0                0.0                 0.0
# min    9.025877e+07                      1.0                   1.0                1.0                 1.0
# 25%    9.027520e+07                      1.0                   1.0                1.0                 1.0
# 50%    9.027780e+07                      1.0                   1.0                1.0                 1.0
# 75%    9.028242e+07                      1.0                   1.0                1.0                 1.0
# max    9.031480e+07                      1.0                   1.0                1.0                 1.0

# %%
df.describe(include=['O'])
# Out:
#        Q1: GOING OUT? Q2: GENDER  ...  Q11: DAY Click Coordinates (x, y)
# count            2350       2419  ...      1735                     1605
# unique              2          4  ...         2                      952
# top                No       Male  ...    Friday                 (77, 24)
# freq             2038       1467  ...      1091                        9
#
# [4 rows x 115 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2460 entries, 0 to 2459
# Columns: 120 entries, Internal ID to Click Coordinates (x, y)
# dtypes: float64(4), int64(1), object(115)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()
# Out:
# Internal ID                                                                                  0
# Q1: GOING OUT?                                                                             110
# Q2: GENDER                                                                                  41
# Q3: AGE                                                                                     84
# Q4: COUNTRY                                                                                 64
# Q5: STATE, PROVINCE, COUNTY, ETC                                                           100
# Q6 | 100 Grand Bar                                                                         747
# Q6 | Anonymous brown globs that come in black and orange wrappers\t(a.k.a. Mary Janes)     734
# Q6 | Any full-sized candy bar                                                              672
# Q6 | Black Jacks                                                                           958
# Q6 | Bonkers (the candy)                                                                   992
# Q6 | Bonkers (the board game)                                                             1006
# Q6 | Bottle Caps                                                                           765
# Q6 | Box'o'Raisins                                                                         688
# Q6 | Broken glow stick                                                                     706
# Q6 | Butterfinger                                                                          682
# Q6 | Cadbury Creme Eggs                                                                    683
# Q6 | Candy Corn                                                                            678
# Q6 | Candy that is clearly just the stuff given out for free at restaurants                691
# Q6 | Caramellos                                                                            752
# Q6 | Cash, or other forms of legal tender                                                  680
# Q6 | Chardonnay                                                                            743
# Q6 | Chick-o-Sticks (we don’t know what that is)                                           946
# Q6 | Chiclets                                                                              711
# Q6 | Coffee Crisp                                                                          853
# Q6 | Creepy Religious comics/Chick Tracts                                                  704
# Q6 | Dental paraphenalia                                                                   692
# Q6 | Dots                                                                                  729
# Q6 | Dove Bars                                                                             702
# Q6 | Fuzzy Peaches                                                                         823
# Q6 | Generic Brand Acetaminophen                                                           731
# Q6 | Glow sticks                                                                           697
# Q6 | Goo Goo Clusters                                                                      879
# Q6 | Good N' Plenty                                                                        734
# Q6 | Gum from baseball cards                                                               716
# Q6 | Gummy Bears straight up                                                               697
# Q6 | Hard Candy                                                                            695
# Q6 | Healthy Fruit                                                                         694
# Q6 | Heath Bar                                                                             712
# Q6 | Hershey's Dark Chocolate                                                              673
# Q6 | Hershey’s Milk Chocolate                                                              672
# Q6 | Hershey's Kisses                                                                      678
# Q6 | Hugs (actual physical hugs)                                                           713
# Q6 | Jolly Rancher (bad flavor)                                                            694
# Q6 | Jolly Ranchers (good flavor)                                                          695
# Q6 | JoyJoy (Mit Iodine!)                                                                 1026
# Q6 | Junior Mints                                                                          698
# Q6 | Senior Mints                                                                          942
# Q6 | Kale smoothie                                                                         744
# Q6 | Kinder Happy Hippo                                                                    945
# Q6 | Kit Kat                                                                               674
# Q6 | LaffyTaffy                                                                            736
# Q6 | LemonHeads                                                                            730
# Q6 | Licorice (not black)                                                                  686
# Q6 | Licorice (yes black)                                                                  685
# Q6 | Lindt Truffle                                                                         718
# Q6 | Lollipops                                                                             691
# Q6 | Mars                                                                                  725
# Q6 | Maynards                                                                             1024
# Q6 | Mike and Ike                                                                          729
# Q6 | Milk Duds                                                                             693
# Q6 | Milky Way                                                                             688
# Q6 | Regular M&Ms                                                                          675
# Q6 | Peanut M&M’s                                                                          671
# Q6 | Blue M&M's                                                                            727
# Q6 | Red M&M's                                                                             729
# Q6 | Green Party M&M's                                                                     764
# Q6 | Independent M&M's                                                                     813
# Q6 | Abstained from M&M'ing.                                                               942
# Q6 | Minibags of chips                                                                     724
# Q6 | Mint Kisses                                                                           776
# Q6 | Mint Juleps                                                                           811
# Q6 | Mr. Goodbar                                                                           740
# Q6 | Necco Wafers                                                                          744
# Q6 | Nerds                                                                                 723
# Q6 | Nestle Crunch                                                                         698
# Q6 | Now'n'Laters                                                                          817
# Q6 | Peeps                                                                                 710
# Q6 | Pencils                                                                               709
# Q6 | Pixy Stix                                                                             722
# Q6 | Real Housewives of Orange County Season 9 Blue-Ray                                    753
# Q6 | Reese’s Peanut Butter Cups                                                            679
# Q6 | Reese's Pieces                                                                        691
# Q6 | Reggie Jackson Bar                                                                   1014
# Q6 | Rolos                                                                                 714
# Q6 | Sandwich-sized bags filled with BooBerry Crunch                                       776
# Q6 | Skittles                                                                              706
# Q6 | Smarties (American)                                                                   725
# Q6 | Smarties (Commonwealth)                                                               901
# Q6 | Snickers                                                                              690
# Q6 | Sourpatch Kids (i.e. abominations of nature)                                          738
# Q6 | Spotted Dick                                                                          882
# Q6 | Starburst                                                                             693
# Q6 | Sweet Tarts                                                                           708
# Q6 | Swedish Fish                                                                          715
# Q6 | Sweetums (a friend to diabetes)                                                      1002
# Q6 | Take 5                                                                                917
# Q6 | Tic Tacs                                                                              714
# Q6 | Those odd marshmallow circus peanut things                                            736
# Q6 | Three Musketeers                                                                      708
# Q6 | Tolberone something or other                                                          706
# Q6 | Trail Mix                                                                             708
# Q6 | Twix                                                                                  690
# Q6 | Vials of pure high fructose corn syrup, for main-lining into your vein                792
# Q6 | Vicodin                                                                               789
# Q6 | Whatchamacallit Bars                                                                  823
# Q6 | White Bread                                                                           757
# Q6 | Whole Wheat anything                                                                  747
# Q6 | York Peppermint Patties                                                               705
# Q7: JOY OTHER                                                                             1549
# Q8: DESPAIR OTHER                                                                         1743
# Q9: OTHER COMMENTS                                                                        2074
# Q10: DRESS                                                                                 744
# Unnamed: 113                                                                              2451
# Q11: DAY                                                                                   725
# Q12: MEDIA [Daily Dish]                                                                   2375
# Q12: MEDIA [Science]                                                                      1098
# Q12: MEDIA [ESPN]                                                                         2361
# Q12: MEDIA [Yahoo]                                                                        2393
# Click Coordinates (x, y)                                                                   855
# dtype: int64

# %%
df.duplicated().any()
# Out:
# False

# %% [markdown]
# # 3- write summary about what you get form the above functions
# > #### tips : this summary can be about : if there is any missing values , if there a wrong data type , if there a wrong range of values , ....

# %% [markdown]
# - #### The data is so messy and needs a lot of cleaning, we have a lot of missing values, we must change columns' names for easeness, we need to correct some types of variables, the data doesn't have any duplicated values.

# %% [markdown]
# # Cleaning

# %% [markdown]
# ### 4- Drop all the useless columns and  rows with too much NaN ,
# > tip : useless columns can be like `Internal ID`and can be also columns with too much NaN
# - rename columns for easy access

# %%
df.drop(['Unnamed: 113', 'Internal ID', 'Q9: OTHER COMMENTS', 'Click Coordinates (x, y)', 'Q8: DESPAIR OTHER', 'Q7: JOY OTHER', ], axis='columns', inplace = True)

# %%
new_names = {'Q1: GOING OUT?': 'going out', 'Q2: GENDER':'sex', 'Q3: AGE': 'age', \
    'Q4: COUNTRY': 'country', 'Q5: STATE, PROVINCE, COUNTY, ETC': 'state', \
    'Q10: DRESS':'dress', 'Q11: DAY':'day', 'Q12: MEDIA [Daily Dish]':'daily dish',\
        'Q12: MEDIA [Science]':'science', 'Q12: MEDIA [ESPN]':'espn', 'Q12: MEDIA [Yahoo]':'yahoo'}
df.rename(columns=new_names, inplace=True)

# %%
df.head()
# Out:
#   going out   sex  age country     state Q6 | 100 Grand Bar  ...           dress     day daily dish science espn yahoo
# 0       NaN   NaN  NaN     NaN       NaN                NaN  ...             NaN     NaN        NaN     NaN  NaN   NaN
# 1        No  Male   44    USA         NM                MEH  ...  White and gold  Sunday        NaN     1.0  NaN   NaN
# 2       NaN  Male   49     USA  Virginia                NaN  ...             NaN     NaN        NaN     NaN  NaN   NaN
# 3        No  Male   40      us        or                MEH  ...  White and gold  Sunday        NaN     1.0  NaN   NaN
# 4        No  Male   23     usa  exton pa                JOY  ...  White and gold  Friday        NaN     1.0  NaN   NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# ### 5 - clean `going out` column
# > tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['going out'].unique()
# Out:
# array([nan, 'No', 'Yes'], dtype=object)

# %%
df['going out'].fillna('Maybe', inplace=True)
print(df['going out'].unique())
df['going out'].value_counts() / df.shape[0] * 100
# Out:
# ['Maybe' 'No' 'Yes']
# No       82.845528
# Yes      12.682927
# Maybe     4.471545
# Name: going out, dtype: float64

# %% [markdown]
# ### 6 - clean ` sex` column
# > tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['sex'].unique()
# Out:
# array([nan, 'Male', 'Female', "I'd rather not say", 'Other'], dtype=object)

# %%
df['sex'].fillna("Didn't say", inplace=True)
df['sex'].replace("I'd rather not say", "Didn't say", inplace=True)
df['sex'].replace("Other", "Didn't say", inplace=True)

print(df['sex'].unique())
df['sex'].value_counts() / df.shape[0] * 100
# Out:
# ["Didn't say" 'Male' 'Female']
# Male          59.634146
# Female        34.105691
# Didn't say     6.260163
# Name: sex, dtype: float64

# %% [markdown]
# ### 7 - clean ` age` column
# > tip : note the type of age column , and NaN values
#  - try to use `to_numeric`
#  - tip : you should choose which best value to put in place of these NaNs ( mean, median, ....etc)

# %%
df['age'].unique()
# Out:
# array([nan, 44, 49, 40, 23, 53, 33, 43, 56, 64, 37, 59, 48, 54, 36, 45,
#        25, 34, 35, 38, 58, 50, 47, 16, 52, 63, 65, 41, 27, 31, 61, 46, 42,
#        62, 29, 39, 32, 28, 69, 67, 30, 22, 26, 51, 70, 24, 18, 19,
#        'Old enough', 57, 60, 66, 12, 'Many', 55, 72, '?', 21, 11, 'no', 9,
#        68, 20, 6, 10, 71, 90, 13, '45-55', 312, 99, 7, 'hahahahaha', 88,
#        39.4, 74, 102, 'older than dirt', 17, 15, 8, 75, '5u', 'Enough',
#        'See question 2', '24-50', 14, 'Over 50', 100, 76, 1000,
#        'sixty-nine', '46 Halloweens.', 'ancient', 77, 'OLD', 'old', 73,
#        70.5, 1, 'MY NAME JEFF', 4, '59 on the day after Halloween',
#        'old enough', 'your mom',
#        'I can remember when Java was a cool new language', '60+'],
#       dtype=object)

# %%
df['age'] = pd.to_numeric(df['age'], errors='coerce')
df['age'].fillna(np.nan, inplace=True)

df['age'].describe()
# Out:
# count    2352.000000
# mean       42.617304
# std        23.846531
# min         1.000000
# 25%        34.000000
# 50%        41.000000
# 75%        50.000000
# max      1000.000000
# Name: age, dtype: float64

# %%
sns.boxplot(x=df['age'])
# Out:
# <AxesSubplot:xlabel='age'>

# %%
q1 = df['age'].quantile(0.25)
q3 = df['age'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - (1.5 * iqr)
upper_bound = q3 + (1.5 * iqr)
df['age'] = df['age'].apply(lambda x: np.nan if x < lower_bound or x > upper_bound else x)

# %%
df['age'].isnull().sum()
# Out:
# 135

# %%
df['age'].fillna(df['age'].median(), inplace=True)
df['age'] = df['age'].astype(int)

# %%
sns.kdeplot(df['age'], shade=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %%
print(df['age'].isnull().sum().any())
df['age'].dtype
# Out:
# False
# dtype('int32')

# %% [markdown]
# ### 8 - clean ` country` column
# > tip : note that country column has country names with different writing ways
#   - use fuzzywuzzy to deal with this problem
#   - you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['country'].unique()
# Out:
# array([nan, 'USA ', 'USA', 'us', 'usa', 'canada', 'Canada', 'Us', 'US',
#        'Murica', 'United States', 'uk', 'United Kingdom', 'united states',
#        'Usa', 'United States ', 'United staes',
#        'United States of America', 'UAE', 'England', 'UK', 'canada ',
#        'Mexico', 'United states', 'u.s.a.', 'USAUSAUSA', 'america', 35,
#        'france', 'United States of America ', 'U.S.A.', 'finland',
#        'unhinged states', 'Canada ', 'united states of america',
#        'US of A', 'Unites States', 'The United States', 'North Carolina ',
#        'Unied States', 'Netherlands', 'germany', 'Europe', 'Earth', 'U S',
#        'u.s.', 'U.K. ', 'Costa Rica', 'The United States of America',
#        'unite states', 'U.S.', 46, 'cascadia', 'Australia',
#        'insanity lately', 'Greece', 'USA? Hard to tell anymore..',
#        "'merica", 'usas', 'Pittsburgh', 45, 'United State', 32, 'France',
#        'australia', 'A', 'Can', 'Canae', 'New York', 'Trumpistan',
#        'Ireland', 'United Sates', 'Korea', 'California', 'Japan', 'USa',
#        'South africa',
#        'I pretend to be from Canada, but I am really from the United States.',
#        'Usa ', 'Uk', 'Iceland', 'Germany', 'Canada`', 'Scotland', 'UK ',
#        'Denmark', 'United Stated', 'France ', 'Switzerland',
#        'Ahem....Amerca', 'UD', 'Scotland ', 'South Korea', 'New Jersey',
#        'CANADA', 'Indonesia', 'United ststes', 'America',
#        'The Netherlands', 'United Statss', 'endland', 'Atlantis',
#        'murrika', 'USA! USA! USA!', 'USAA', 'Alaska', 'united States ',
#        'soviet canuckistan', 'N. America', 'Singapore', 'USSA', 'China',
#        'Taiwan', 'Ireland ', 'hong kong', 'spain', 'Sweden', 'Hong Kong',
#        'U.S. ', 'Narnia', 'u s a', 'United Statea', 'united ststes', 1,
#        'subscribe to dm4uz3 on youtube', 'United kingdom',
#        'USA USA USA!!!!', "I don't know anymore", 'Fear and Loathing'],
#       dtype=object)

# %%
from fuzzywuzzy import process

val_countries = ['usa', 'united states', 'united states of america', 'america', 'uk', 'england', 'united kingdom', \
    'japan', 'canada', 'france', 'germany', 'spain', 'australia', 'sweden', 'switzerland', 'netherlands', 'norway']

df['country'] = df['country'].str.lower()
for country in val_countries:
        matches = process.extract(country, df['country'], limit=df.shape[0])
        for sub in matches:
            if sub[1] >= 80:
                df.loc[df['country'] == sub[0], 'country'] = country

# %%
df['country'].unique()
# Out:
# array([nan, 'usa', 'canada', 'murica', 'america', 'uk', 'uae', 'england',
#        'mexico', 'u.s.a.', 'france', 'finland', 'north carolina ',
#        'netherlands', 'germany', 'europe', 'earth', 'costa rica',
#        'cascadia', 'australia', 'insanity lately', 'greece',
#        'usa? hard to tell anymore..', 'pittsburgh', 'canae', 'new york',
#        'trumpistan', 'ireland', 'korea', 'california', 'japan',
#        'south africa', 'iceland', 'scotland', 'denmark', 'switzerland',
#        'ud', 'scotland ', 'south korea', 'new jersey', 'indonesia',
#        'atlantis', 'murrika', 'alaska', 'soviet canuckistan', 'singapore',
#        'china', 'taiwan', 'ireland ', 'hong kong', 'spain', 'sweden',
#        'narnia', 'u s a', 'subscribe to dm4uz3 on youtube',
#        "i don't know anymore", 'fear and loathing'], dtype=object)

# %%
true_countries = {'america': 'usa', 'murica':'usa', 'u.s.a.':'usa', 'england':'uk', 'new york': 'usa', 'north carolina': 'usa', 'cascadia':'usa', \
    'usa? hard to tell anymore..':'usa', 'pittsburgh':'usa', 'canae':'canada', 'california':'usa', 'ud':'uk', 'new jersey':'usa', 'soviet canuckistan':'canada', \
        'murrika':'usa', 'u s a':'usa', 'hong kong': 'china'}

df['country'].replace(true_countries, inplace=True)
df.value_counts('country') / df.shape[0] * 100
# Out:
# country
# usa                               83.821138
# canada                             9.268293
# uk                                 0.894309
# germany                            0.406504
# australia                          0.284553
# netherlands                        0.284553
# japan                              0.203252
# china                              0.162602
# mexico                             0.162602
# scotland                           0.162602
# france                             0.121951
# switzerland                        0.121951
# ireland                            0.121951
# sweden                             0.081301
# denmark                            0.081301
# spain                              0.040650
# singapore                          0.040650
# south africa                       0.040650
# south korea                        0.040650
# earth                              0.040650
# subscribe to dm4uz3 on youtube     0.040650
# taiwan                             0.040650
# trumpistan                         0.040650
# uae                                0.040650
# scotland                           0.040650
# narnia                             0.040650
# north carolina                     0.040650
# costa rica                         0.040650
# europe                             0.040650
# korea                              0.040650
# atlantis                           0.040650
# ireland                            0.040650
# insanity lately                    0.040650
# indonesia                          0.040650
# iceland                            0.040650
# i don't know anymore               0.040650
# greece                             0.040650
# finland                            0.040650
# fear and loathing                  0.040650
# alaska                             0.040650
# dtype: float64

# %%
last_countries = ['usa', 'canada', 'uk', 'germany', 'australia', 'netherlands', 'japan',\
    'china', 'mexico', 'scotland', 'france', 'switzerland', 'ireland']

df['country'] = df['country'].apply(lambda x: x if x in last_countries else 'other')
df['country'].value_counts() / df.shape[0] * 100
# Out:
# usa            83.821138
# canada          9.268293
# other           3.983740
# uk              0.894309
# germany         0.406504
# netherlands     0.284553
# australia       0.284553
# japan           0.203252
# mexico          0.162602
# scotland        0.162602
# china           0.162602
# france          0.121951
# ireland         0.121951
# switzerland     0.121951
# Name: country, dtype: float64

# %% [markdown]
# ### 9 - clean ` state` column
# > tip : area column has the same problem as country columns , but looking at all it's unique values may give us another way to deal with it rather than try to fix it

# %%
df['state'].unique()
# Out:
# array([nan, 'NM', 'Virginia', 'or', 'exton pa', 'Colorado ', 'ontario',
#        'Ontario', 'Wa', 'Quebec', 'NY', 'California', 'Texas', 'NEW YORK',
#        'CO', 'IN', 'MN', 'aberdeenshire', 'Alberta', 'Wisconsin, 53705',
#        'RI', 'NC', 'Scotland', 'minnesota', 'Michigan', 'Florida',
#        'New Jersey', 'VA', 'Colorado', 'Los Angeles, California', 'CA',
#        'New York ', 'Chicago, Illinois', 'Nj', 'Wisconsin', 'Minnesota ',
#        'London', 'mn', 'TEXAS', 'Illinois', 'District of Columbia',
#        'Washington', 'Massachusetts ', 'OR', 'Montana', 'New York',
#        'massachusetts', 'Abu Dhabi', 'TX', 'Arizona', 'Dc', 'yukon',
#        'Pennsylvania ', 'MD', 'Ohio', 'Alberta ', 'OXFORDSHIRE', 'DC',
#        'Iowa', 'Mn', 'TN', 'BC', 'Maryland', 'MI', 'Wisconsin ', 'alaska',
#        'Ny', 'Colorado, Jefferson county ', 'Louisiana', 'pa',
#        'CO, Larimer County', 'Nebraska ', 'Oregon', 'UT', 'ny',
#        'Pennsylvania', 'CDMX', 'north carolina', 'Tennessee ', 'Texas ',
#        'Knox county, Tennessee', 'New Mexico', 'Maine', 'maine',
#        'Virginia, Arlington', 'WA', 'MO', 'Illinois ', 'Mi', 'MA',
#        'Alaska', 'New York, NY', 'Il', 'PA', 'New Hampshire ',
#        'Washington ', 'Massachusetts', 'Georgia', 'IL', 'Oregon ',
#        'Washington, Clark ', 'NE', 'Oklahoma', 'SC', 'Nebraska', 'mi',
#        'Nevada', 'va', 'California ', 'vancouver, bc',
#        'Oregon - but will be in Washington for Halloween', 'Ri',
#        'Washington, King', 'Ca', 'wa', 'md', 'new york', 'Rhode island',
#        'VT, Chittenden', 'North Carolina', 'pennsylvania', 'PEnnsylvania',
#        'Alabama', 'GA', 'FL, Orange County', 'Nope', 'manitoba',
#        'colorado', 'california ', 'South Carolina', 'california',
#        'Baja California', 'illinois', 'Santa Cruz County, California',
#        'MARYLAND', 'NJ', 'North Dakota',
#        'Pennsylvania, Montgomery County', 'Astoria NY', 'Michigan ', 'ca',
#        'Kansas ', 'sk', 'Missouri', 'Oxfordshire', 'British Columbia',
#        'West Virginia', 'Harris County, Texas', 'USA ', 'ohio', 'ma',
#        'nc', 'Minnesota', 'Bc', 'oregon', 'philadelphia', 'Kentucky',
#        'HI', 'South Holland', 'Derbyshire', 'hesse',
#        'Massachusetts, Plymouth county', 'hi', 'Co', 'Cali', 'vt',
#        'CA, Alameda', 'Utah', 'FL', 'Michigan, Shiawassee County',
#        'Newfoundland', 'Indiana', 'wisconsin', 'Idaho ada', 'La',
#        'America', 'Hawaii', 'California, Alameda', 'Az', 'VT', 'AZ',
#        'Sub Earth', 'North dakota', 'virginia', 'Ga',
#        'alameda county, california', 'Greater London', 'bc', 'nm', 'AB',
#        'WV, Kanawha County ', 'michigan', 'Florida ', 'tx',
#        'Washington State', 'Sussex', 48, 'Washington, King County',
#        'San Jose', 'florida', 'Connecticut', 'New Jersey ', 'Orlando, FL',
#        'ON', 'Saskatchewan', 'South Carolina ', 'texas', 'newfoundland',
#        'mississippi', 'Oklahoma ', 'washington', 'Manitoba ',
#        'Manchester', 'cascadia', 'in', 'rhode island', 'Ohio ', 'Pa',
#        'FL ', 'Ut', 'Sydney ', 'CT',
#        'oblivion if things keep going this way', 'connecticut',
#        'British Columbia ', 'Nunya, Bizness, USA', 'OH',
#        'Washington state', 'Oakland, California',
#        'Washington, Seattle, king', 'Ontario,  Canada', 'ri',
#        'phoenix, maricopa county, arizona', 'Merlin', 'NS',
#        'Washington state, Kitsap County', 'cailifornia', 'oakland,ca',
#        'QC', 'USA', 'Missouri ', 'Pittsburgh pa',
#        'Issaquah, WA, King County ', 'Washington, seattle, king',
#        'Massachussets ', 'Whatcom County, WA', 'Mt', 'NH', 'Michigin',
#        'Ma', 'KS', 'Oakland County, Michigan', 'Albeqrrta', 'Marne',
#        'Noord-Holland', 'Tennessee, Knox County', 'Henrico, VA',
#        'Washington State, King County, City of Seattle', 'Washington, DC',
#        'nyc', 'Brooklyn', 'qld', 'Santa Barbara co. California',
#        'Maryland ', 'Ky', 'New Orleans la ', 'colorado, boulder', 'mo',
#        'COLORADO', 'Nh', 'Greater Manchester', 'Fife, Scotland', 'A',
#        'Kalamazoo County, MI', 'OREGON', 'Wi', 'Ontario ', 'wv',
#        'ulster county, NY', 'NJ, Gloucester', 'calif', 'Or', 'tn', 'MS',
#        'NB', 'Queens', 'Vermont', 'Kildare', 'Vermont ', 'ND',
#        'tennessee', 'Washington DC', 'Kings, New York ', 'Cook',
#        'Toronto, Ontario', 'Victoria', 'Virginia ', 'On', 'nova scotia',
#        'Tehama', 'suffolk county ny', 'Santa Clara County, California',
#        'louisiana', 'SD', 'Md', 'Missoure', 'IA',
#        'Colorado larimer county', 'Tokyo', 'New Mexico, USA', 'ont',
#        'Califor', 'Idaho', 'Kansas', 'NV', 'Brooklyn, kings county ny',
#        'King County, Washington', 'WI', 'Washington, Island county',
#        'KwaZulu-Natal', 'Carver county, MN', 'DUTCHESS COUNTY NY', 'Ny ',
#        'Wyoming ', 'Bristol ', 'british columbia',
#        'California, San Francisco', 'Glendora, Los Angeles, California',
#        'Edinburgh', 'Strathclyde', 'Lancasire', 'Ørbæk', 'pr', 'Idf',
#        'Zuid Holland', 'Osaka', 'Surrey', 'Northern ireland', 'Vaud',
#        'Arizona ', 'Nova Scotia', 'az', 'see question 2', 'Midlothian',
#        'Tennessee', 'Durham County, North Carolina',
#        'Missouri, Miller County', 'Glasgow ', 'ct',
#        'Cuyahoga County, Ohio', 'Seoul', 'Canada', 'Kanagawa ',
#        'The Shore', 'Manitoba', 'MD ', 'Devonshire', 'Utah ', 'Tx.',
#        'maryland', 'PENNSYLVANIA', 'ONTARIO', 'Jakarta', 'kansas',
#        'Mannheim, Baden-Württemberg ', '|NC', 'Wyoming', 'Rotterdam',
#        'Ar', 'Arkansas', 'renton,wa ', 'N-Brabant', 'missouri',
#        'Georgia ', 'Greifswald', 'ar', 'British Columbia, Canada', 'kent',
#        'Hessen', 'Kentucky ', 'NOYB', 'New york', 'South Dakota',
#        'Emerald City, Petrolia', 'New York, New York', 'wa, spokane',
#        'new york ', 'Buncombe County, North Carolina',
#        'California, San Diego', 'new hampshire',
#        'California, Ventura County', 'NY, Tompkins County', 'Nj ',
#        'Arlington, VA', 'Glasgow', 'kentucky', 'alberta', 'Philadelphia',
#        'Portland, maine', 'sc', 'nh', 'NSW', 'califormia', 'New jersey',
#        'montana', 'indiana ', 'Mexico city', 'GA - Georgia', 'il', 'WV',
#        'Oregon, Multnomah County', 'Vancouver, Wa', 'Nc', 'Atlanta, GA',
#        'Washington state ', 'Singapore', 'west virginia',
#        'North carolina', 'KY', 'United States', 'Mo', 'Colorado (CO)',
#        'Fl', 'wyoming', 'Nm', 'Dona Ana county, New Mexico',
#        'UT, Salt Lake', 'Ks',
#        'California, Contra Costa County, Pleasant Hill',
#        'Shanghai, Chang Ning district ', 'Vt', 'Monroe county',
#        'Hong Kong', 'Washingto', 'Dublin ',
#        'California, Mendocino County', 'na', 'madrid', 'Hesse',
#        'Noord-Brabant', 'Skane', 'Zürich', 'Tree Town, USA',
#        'New Hampshire', 'Philadelphia, PA',
#        'Bristol County, Rhode Island', 'georgia',
#        'Newfoundland and Labrador', 'Dublin', 'Oshawa, Ontario, Canada',
#        'NL', 'DC ', 'oklahoma', 'NJ; Essex', 'Va', 'Delaware', 'Mich',
#        'Ia', 'Québec', 'orange county, ca', 'BERKELEY, CA',
#        'California, USA', 'NYC', 'St. Louis County, Missouri', 'Munster',
#        'Chicago, IL', 'Philadelphia PA', 'Rappahannock County, VA', 'OK',
#        'Chicago, IL ', 'Mexico City', 'dc', 'Illinois  ', 'WASHINGTON DC',
#        'Tn', 'Connecticut ', 'ill', 'Idaho ', 'Stockholm',
#        'New York County, New York City, New York State', 'Chicago',
#        'West Yorkshire', 'Berlin', 'arlington, va', 1, 'ur mom',
#        'Alaska, Matanuska-Susitna Borough', 'utah', 'Marietta, GA',
#        'Northbrook, IL', 'delaware', 'Tx', 'Ont',
#        'Northampton County, PA', 'Rhode Island',
#        'Pa.   Northampton county', 'California, San Diego county',
#        'Bloomington, IN', 'indiana', 'Quenec', 'Londom', 'nj',
#        'st. augustine florida', 'illinois ', 'iowa',
#        "The Democratic People's Republic of North Carolina", 'SC ',
#        'pennsylvania, northampton couny, easton', 'St Louis mo', 'mt',
#        'Psychotic', 'québec'], dtype=object)

# %%
df.drop('state', axis='columns', inplace=True)

# %% [markdown]
# ### 10 - clean ` Q6` columns
# >- tip : Q6 has all kinds of chocolate bars and questions with three distinct options to choose from (Joy, Meh, Despair).
# - so all the column that has Q6 is a candy name , so you should go through all these column and you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
for col in df.columns:
    if col.startswith('Q6'):
        df[col].fillna('Unknown', inplace=True)

# %%
for col in df.columns[4:-6]:
    df.rename(columns={col: col[5:]}, inplace=True)

# %% [markdown]
# ### 11 - clean ` dress` column
# >tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['dress'].unique()
# Out:
# array([nan, 'White and gold', 'Blue and black'], dtype=object)

# %%
df['dress'].fillna('Other', inplace=True)

# %% [markdown]
# ### 12 - clean ` day` column
# >tip : you should choose which best value to put in place of these NaNs ( mode, unknown,other ....etc)

# %%
df['day'].unique()
# Out:
# array([nan, 'Sunday', 'Friday'], dtype=object)

# %%
df['day'].fillna('Other', inplace=True)

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# daily dish    2375
# science       1098
# espn          2361
# yahoo         2393
# dtype: int64

# %%
for col in df.columns[-4:]:
    df[col].fillna(0, inplace=True)

# %%
df['No page'] = (df['daily dish'] + df['science'] + df['espn'] + df['yahoo']).apply(lambda x: 1 if x == 0 else 0)

# %%
for col in df.columns[-5:]:
    df[col] = df[col].astype(int)
    print(df[col].value_counts(normalize=True) * 100, '\n')
# Out:
# 0    96.544715
# 1     3.455285
# Name: daily dish, dtype: float64
#
# 1    55.365854
# 0    44.634146
# Name: science, dtype: float64
#
# 0    95.97561
# 1     4.02439
# Name: espn, dtype: float64
#
# 0    97.276423
# 1     2.723577
# Name: yahoo, dtype: float64
#
# 0    65.569106
# 1    34.430894
# Name: No page, dtype: float64

# %% [markdown]
# ### 13 - check
# > after finish cleaning you should make sure your data is clean and that :
# - there is no wrong data type
# - there is no NaN values
# - all the column are cleaing and ready for the next step `EDA`

# %%
check = pd.DataFrame({"Type": df.dtypes, "Null": [df[col].isnull().sum() for col in df.columns]})
check
# Out:
#                                                       Type  Null
# going out                                           object     0
# sex                                                 object     0
# age                                                  int32     0
# country                                             object     0
# 100 Grand Bar                                       object     0
# Anonymous brown globs that come in black and or...  object     0
# Any full-sized candy bar                            object     0
# Black Jacks                                         object     0
# Bonkers (the candy)                                 object     0
# Bonkers (the board game)                            object     0
# Bottle Caps                                         object     0
# Box'o'Raisins                                       object     0
# Broken glow stick                                   object     0
# Butterfinger                                        object     0
# Cadbury Creme Eggs                                  object     0
# Candy Corn                                          object     0
# Candy that is clearly just the stuff given out ...  object     0
# Caramellos                                          object     0
# Cash, or other forms of legal tender                object     0
# Chardonnay                                          object     0
# Chick-o-Sticks (we don’t know what that is)         object     0
# Chiclets                                            object     0
# Coffee Crisp                                        object     0
# Creepy Religious comics/Chick Tracts                object     0
# Dental paraphenalia                                 object     0
# Dots                                                object     0
# Dove Bars                                           object     0
# Fuzzy Peaches                                       object     0
# Generic Brand Acetaminophen                         object     0
# Glow sticks                                         object     0
# Goo Goo Clusters                                    object     0
# Good N' Plenty                                      object     0
# Gum from baseball cards                             object     0
# Gummy Bears straight up                             object     0
# Hard Candy                                          object     0
# Healthy Fruit                                       object     0
# Heath Bar                                           object     0
# Hershey's Dark Chocolate                            object     0
# Hershey’s Milk Chocolate                            object     0
# Hershey's Kisses                                    object     0
# Hugs (actual physical hugs)                         object     0
# Jolly Rancher (bad flavor)                          object     0
# Jolly Ranchers (good flavor)                        object     0
# JoyJoy (Mit Iodine!)                                object     0
# Junior Mints                                        object     0
# Senior Mints                                        object     0
# Kale smoothie                                       object     0
# Kinder Happy Hippo                                  object     0
# Kit Kat                                             object     0
# LaffyTaffy                                          object     0
# LemonHeads                                          object     0
# Licorice (not black)                                object     0
# Licorice (yes black)                                object     0
# Lindt Truffle                                       object     0
# Lollipops                                           object     0
# Mars                                                object     0
# Maynards                                            object     0
# Mike and Ike                                        object     0
# Milk Duds                                           object     0
# Milky Way                                           object     0
# Regular M&Ms                                        object     0
# Peanut M&M’s                                        object     0
# Blue M&M's                                          object     0
# Red M&M's                                           object     0
# Green Party M&M's                                   object     0
# Independent M&M's                                   object     0
# Abstained from M&M'ing.                             object     0
# Minibags of chips                                   object     0
# Mint Kisses                                         object     0
# Mint Juleps                                         object     0
# Mr. Goodbar                                         object     0
# Necco Wafers                                        object     0
# Nerds                                               object     0
# Nestle Crunch                                       object     0
# Now'n'Laters                                        object     0
# Peeps                                               object     0
# Pencils                                             object     0
# Pixy Stix                                           object     0
# Real Housewives of Orange County Season 9 Blue-Ray  object     0
# Reese’s Peanut Butter Cups                          object     0
# Reese's Pieces                                      object     0
# Reggie Jackson Bar                                  object     0
# Rolos                                               object     0
# Sandwich-sized bags filled with BooBerry Crunch     object     0
# Skittles                                            object     0
# Smarties (American)                                 object     0
# Smarties (Commonwealth)                             object     0
# Snickers                                            object     0
# Sourpatch Kids (i.e. abominations of nature)        object     0
# Spotted Dick                                        object     0
# Starburst                                           object     0
# Sweet Tarts                                         object     0
# Swedish Fish                                        object     0
# Sweetums (a friend to diabetes)                     object     0
# Take 5                                              object     0
# Tic Tacs                                            object     0
# Those odd marshmallow circus peanut things          object     0
# Three Musketeers                                    object     0
# Tolberone something or other                        object     0
# Trail Mix                                           object     0
# Twix                                                object     0
# Vials of pure high fructose corn syrup, for mai...  object     0
# Vicodin                                             object     0
# Whatchamacallit Bars                                object     0
# White Bread                                         object     0
# Whole Wheat anything                                object     0
# York Peppermint Patties                             object     0
# dress                                               object     0
# day                                                 object     0
# daily dish                                           int32     0
# science                                              int32     0
# espn                                                 int32     0
# yahoo                                                int32     0
# No page                                              int32     0

# %%
des = df.describe(include=['O'])
des
# Out:
#        going out   sex country 100 Grand Bar  ... Whole Wheat anything York Peppermint Patties           dress     day
# count       2460  2460    2460          2460  ...                 2460                    2460            2460    2460
# unique         3     3      14             4  ...                    4                       4               3       3
# top           No  Male     usa           JOY  ...              DESPAIR                     JOY  White and gold  Friday
# freq        2038  1467    2062           873  ...                 1289                    1105            1081    1091
#
# [4 rows x 108 columns]

# %%
des_2 = des.iloc[[2, 3], 3:-2].T
print("These are the 10 most loved chocolates:")
top_joy = des_2.sort_values(by='freq', ascending=False)[des_2.sort_values(by='freq', ascending=False)['top'] == "JOY"].head(10)


ax = sns.barplot(y = top_joy.index, x = 'freq', palette = 'viridis', data=top_joy)
for i, v in enumerate(top_joy['freq']):
    ax.text(v + 1, i + .25, str(round(v, 2)), color='black', fontweight='bold')
plt.title("Top 10 most loved chocolates")
plt.xlabel("Frequency")
plt.ylabel("Chocolates")
plt.show()
# Out:
# These are the 10 most loved chocolates:

# %%
print("These are the 10 most hated chocolates:")

top_despair = des_2.sort_values(by='freq', ascending=False)[des_2.sort_values(by='freq', ascending=False)['top'] == "DESPAIR"].head(10)

ax = sns.barplot(y = top_despair.index, x = 'freq', palette = 'flare', data=top_despair)
for i, v in enumerate(top_despair['freq']):
    ax.text(v + 1, i + .25, str(round(v, 2)), color='black', fontweight='bold')
plt.title("Top 10 most hated chocolates")
plt.xlabel("Frequency")
plt.ylabel("Chocolates")
plt.show()
# Out:
# These are the 10 most hated chocolates:

# %% [markdown]
# #### So now we have a clean data and demostrated what are the most 10 hated and loved chocolates in the world.

# %% [markdown]
# ### 14 - write a summary about all the cleaning steps

# %% [markdown]
# - First, we dropped all the useless columns and columns with too much NaN.
# - Then, we renamed columns for easeness.
# - We cleaned the going out column by replacing NaNs with the 'Maybe' word.
# - We cleaned the sex column by replacing NaNs with the 'Didn't say' word.
# - We cleaned the age column by replacing NaNs with the median of the ages.
# - We cleaned the country column by replacing NaNs with the 'Other' word, and we used fuzzywuzzy to deal with the problem of different writing ways.
# - We cleaned the area column by dropping it.
# - We cleaned the Q6 columns by replacing NaNs with the 'Unknown' word.
# - We cleaned the dress column by replacing NaNs with the 'Other' word.
# - We cleaned the day column by replacing NaNs with the 'Other' word.
# - Finally, we checked the data and made sure that there is no wrong data type, no NaN values, and all the columns are clean and ready for the next step EDA.
